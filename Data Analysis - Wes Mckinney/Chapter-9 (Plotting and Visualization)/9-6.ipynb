# %% [markdown]
# Mas graficos con seaborn

# %%
from pathlib import Path
import pandas as pd
import seaborn as sns
import numpy as np  

macro = pd.read_csv(Path(r"D:\Documentos\GitHub\Python\Data Analysis - Wes Mckinney\Chapter-9 (Plotting and Visualization)\macrodata.csv"), sep=",", encoding="utf8", header=0)
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna()
sns.regplot(x='m1', y='unemp', data=trans_data)
# Out:
# <AxesSubplot:xlabel='m1', ylabel='unemp'>

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2})
