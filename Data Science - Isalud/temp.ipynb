# %%
import pandas as pd
import seaborn as sns
from pathlib import Path

df = pd.read_csv(Path(r"Files\cardio_train.zip"), sep=";",
                 encoding="utf8", header=0, index_col=False,  engine="c")

df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df['years'] = (df['age'] / 365).round().astype('int')

sns.countplot(x="gender", data=df, hue="cardio", palette="Set2")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
df_categorical = df.loc[:,['cholesterol','gluc', 'smoke', 'alco', 'active']]
sns.countplot(x="variable", hue="value",data= pd.melt(df_categorical))
# Out:
# <AxesSubplot:xlabel='variable', ylabel='count'>

# %%
df.groupby(["gender", "active"]).head()
# Out:
#     id    age  gender height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0    0  18393       2    168    62.0    110     80            1     1      0
# 1    1  20228       1    156    85.0    140     90            3     1      0
# 2    2  18857       1    165    64.0    130     70            3     1      0
# 3    3  17623       2    169    82.0    150    100            1     1      0
# 4    4  17474       1    156    56.0    100     60            1     1      0
# 5    8  21914       1    151    67.0    120     80            2     2      0
# 6    9  22113       1    157    93.0    130     80            3     1      0
# 7   12  22584       2    178    95.0    130     90            3     3      0
# 8   13  17668       1    158    71.0    110     70            1     1      0
# 9   14  19834       1    164    68.0    110     60            1     1      0
# 10  15  22530       1    169    80.0    120     80            1     1      0
# 11  16  18815       2    173    60.0    120     80            1     1      0
# 12  18  14791       2    165    60.0    120     80            1     1      0
# 13  21  19809       1    158    78.0    110     70            1     1      0
# 14  23  14532       2    181    95.0    130     90            1     1      1
# 15  24  16782       2    172   112.0    120     80            1     1      0
# 16  25  21296       1    170    75.0    130     70            1     1      0
# 29  40  21057       2    169    74.0    130     70            1     3      0
# 34  46  21940       2    173    82.0    140     90            3     1      0
# 47  62  18535       2    168    69.0    120     80            1     1      0
#
#     alco  active  cardio  years
# 0      0       1       0     50
# 1      0       1       1     55
# 2      0       0       1     52
# 3      0       1       1     48
# 4      0       0       0     48
# 5      0       0       0     60
# 6      0       1       0     61
# 7      0       1       1     62
# 8      0       1       0     48
# 9      0       0       0     54
# 10     0       1       0     62
# 11     0       1       0     52
# 12     0       0       0     41
# 13     0       1       0     54
# 14     1       1       0     40
# 15     0       0       1     46
# 16     0       0       0     58
# 29     0       0       0     58
# 34     0       0       1     60
# 47     0       0       0     51
